# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# ## My lane as an ML task
#
# Lane: Refresh / Content Opportunity Scoring
#
# This lane is primarily a classification and ranking problem.
#
# The model predicts whether a page is likely to be at risk of decline. The predicted probability can then be used to rank pages so that editors review the highest priority pages first.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# ## Target or proxy
#
# The starter dataset already provides a proxy target.
#
# Proxy target:
#
# is_declining_label = trend_direction == "down"
#
# This proxy represents whether a page is currently declining. Although it is not a future outcome, it provides a useful starting point for building and evaluating a ranking model.
#
# In a future version of the project, the target could be based on future performance rather than the current trend.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# ## Success metric
#
# The most important success metric is Precision@50.
#
# Editors usually cannot review every page, so the goal is for the top-ranked pages to contain as many true opportunities as possible.
#
# Other useful metrics include:
#
# - ROC AUC
# - Average Precision
# - Recall

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
from pathlib import Path

print(Path.cwd())

from pathlib import Path

for p in Path(".").glob("**/*.csv"):
    print(p)
# Out:
# /content
# sample_data/mnist_test.csv
# sample_data/california_housing_train.csv
# sample_data/mnist_train_small.csv
# sample_data/california_housing_test.csv

# %%
import pandas as pd

df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")

df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2261/562931108.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")
#       4
#       5 df.head()
#
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
